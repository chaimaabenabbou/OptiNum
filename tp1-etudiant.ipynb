# %% [markdown]
# # Reconstruction parcimonieuse ou compressive sensing

# %% [markdown]
# ## I. Cadre général et première tentative.

# %% [markdown]
# Le but du TP est de montrer que des techniques d'optimisation pour le Machine Learning permettent de récupérer des signaux qui admettent dans une certaine base une représentation parcimonieuse, c'est à dire mettant en jeu un faible nombre de coefficients.
#
# On s'intéresse donc à la reconstruction d'un vecteur $x$ (ici une image codées en niveaux de gris) en utilisant les valeurs de combinaisons aléatoire de certains pixels. Les combinaisons sont représentées par une matrice $\Phi$.
#
# Une première approche consiste à résoudre le problème $$ \min_x \frac{1}{2} ||\Phi x-y||_2^2$$ pour retrouver l'image.
#
# **Question 1 :** Commenter et compléter le code constituant le reste de la section I.

# %%
#
# Installation des librairies
#
#Pkg.update()
#using Pkg
#Pkg.add("Images")
#Pkg.add("ImageMagick")
#Pkg.add("LinearAlgebra")
#Pkg.add("FFTW")
#Pkg.add("Colors")
#
# Repertoire ou se trouve le fichier cameraman.tif
#
#cd("$(homedir())/") 

#
# Chargement des librairies de traitement d'image
#
using Images, Colors, LinearAlgebra, FFTW


img1 = load("cameraman.tif");    # 
img=convert(Array{Gray},img1);   # 
A = float(convert(Array,img));  # 

tmp=@view img1[:,:]
# Out:
# 256×256 view(::Array{Gray{N0f8},2}, :, :) with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)  …  Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)     Gray{N0f8}(0.596)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.6)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.584)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.624)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.604)  Gray{N0f8}(0.616)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.596)  Gray{N0f8}(0.588)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.6)       Gray{N0f8}(0.592)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.522)  Gray{N0f8}(0.482)     Gray{N0f8}(0.384)
#  Gray{N0f8}(0.561)  Gray{N0f8}(0.502)  …  Gray{N0f8}(0.467)
#  Gray{N0f8}(0.318)  Gray{N0f8}(0.416)     Gray{N0f8}(0.38)
#  Gray{N0f8}(0.416)  Gray{N0f8}(0.549)     Gray{N0f8}(0.533)
#  Gray{N0f8}(0.537)  Gray{N0f8}(0.478)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.569)  Gray{N0f8}(0.455)     Gray{N0f8}(0.376)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.482)  …  Gray{N0f8}(0.392)
#  Gray{N0f8}(0.384)  Gray{N0f8}(0.447)     Gray{N0f8}(0.416)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.455)     Gray{N0f8}(0.471)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.518)     Gray{N0f8}(0.447)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)     Gray{N0f8}(0.443)
#  Gray{N0f8}(0.475)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.443)

# %%
# Extraction d'une sous-image contrastée
k    = 30;
orig = 60;
Aloc   = A[orig:orig+k-1,orig:orig+k-1];
x   = (Aloc[:]);
n   = length(x);
m   = 500; 
Phi = randn(m,n);

imhsv=colorview(Gray,float(Aloc));
tmp=@view imhsv[:,:]

#
# Fin Extraction
#
# Out:
# 30×30 view(::Array{Gray{Float32},2}, :, :) with eltype Gray{Float32}:
#  Gray{Float32}(0.705882)   …  Gray{Float32}(0.721569)
#  Gray{Float32}(0.698039)      Gray{Float32}(0.713726)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.729412)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.717647)
#  Gray{Float32}(0.698039)   …  Gray{Float32}(0.764706)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.588235)
#  Gray{Float32}(0.701961)      Gray{Float32}(0.0705882)
#  Gray{Float32}(0.690196)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.709804)      Gray{Float32}(0.0627451)
#  Gray{Float32}(0.701961)   …  Gray{Float32}(0.0627451)
#  Gray{Float32}(0.713726)      Gray{Float32}(0.0588235)
#  Gray{Float32}(0.705882)      Gray{Float32}(0.054902)
#  ⋮                         ⋱
#  Gray{Float32}(0.513726)      Gray{Float32}(0.054902)
#  Gray{Float32}(0.0941176)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)  …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0627451)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0666667)     Gray{Float32}(0.0627451)
#  Gray{Float32}(0.0588235)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.054902)   …  Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0470588)     Gray{Float32}(0.0588235)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0431373)     Gray{Float32}(0.054902)
#  Gray{Float32}(0.0392157)     Gray{Float32}(0.0588235)

# %% [markdown]
# **Question 2 :** Résoudre le problème de moindres carrés $$\min_x || \Phi x -y ||_2,$$ et afficher le résultat (attention, l'image doit être en niveaux de gris). Que constate-t-on?

# %%
y     = Phi*x ; # Vecteur des "observations" de l'image


P1= transpose(Phi)*Phi;
P2 = transpose(Phi)*y;

#resultat = pinv(Phi)*y ;
resultat = pinv(P1)*P2;
R = reshape(resultat,k,k)
#R = 1/(maximum(R)-minimum(R))*(R-minimum(R)*ones(k,k));

#Affichage du resultat
imhsv=colorview(Gray,float(R));
tmp=@view imhsv[:,:]
# Out:
# 30×30 view(::Array{Gray{Float64},2}, :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.13308)      …  Gray{Float64}(0.224434)
#  Gray{Float64}(0.227589)        Gray{Float64}(0.746206)
#  Gray{Float64}(0.654328)        Gray{Float64}(0.4169)
#  Gray{Float64}(0.265539)        Gray{Float64}(0.425783)
#  Gray{Float64}(0.216826)        Gray{Float64}(0.528261)
#  Gray{Float64}(0.319482)     …  Gray{Float64}(-0.0676978)
#  Gray{Float64}(0.501678)        Gray{Float64}(0.646889)
#  Gray{Float64}(0.395331)        Gray{Float64}(0.0555667)
#  Gray{Float64}(0.591146)        Gray{Float64}(-0.0353479)
#  Gray{Float64}(0.258961)        Gray{Float64}(0.141558)
#  Gray{Float64}(0.0735435)    …  Gray{Float64}(-0.017047)
#  Gray{Float64}(0.547486)        Gray{Float64}(0.194913)
#  Gray{Float64}(0.708951)        Gray{Float64}(-0.370156)
#  ⋮                           ⋱
#  Gray{Float64}(0.435512)        Gray{Float64}(0.0688215)
#  Gray{Float64}(-0.0497069)      Gray{Float64}(-0.0675543)
#  Gray{Float64}(0.0338804)    …  Gray{Float64}(0.335348)
#  Gray{Float64}(-0.12945)        Gray{Float64}(0.0127225)
#  Gray{Float64}(0.224161)        Gray{Float64}(0.300374)
#  Gray{Float64}(0.24774)         Gray{Float64}(-0.0418582)
#  Gray{Float64}(-0.0883478)      Gray{Float64}(-0.18552)
#  Gray{Float64}(0.329559)     …  Gray{Float64}(0.0935805)
#  Gray{Float64}(-0.00706232)     Gray{Float64}(0.232609)
#  Gray{Float64}(-0.18049)        Gray{Float64}(0.0113122)
#  Gray{Float64}(0.0417533)       Gray{Float64}(0.502528)
#  Gray{Float64}(0.360426)        Gray{Float64}(-0.163975)

# %% [markdown]
# #### II. Compressive sensing

# %% [markdown]
# On désire utiliser à présent la transformation discrète en cosinus pour obtenir une représentaiton parcimonieuse d'une image. Cette transfomation bijective est obtenue avec la fonction `dct`, son inverse s'appelant `idct`.
#
# ** Question 3 :** A partir de la fonction IDCT de Julia, calculer la matrice  $\Theta = \Phi*\Psi$, avec $\Psi$ la matrice représentative de IDCT dans la base canonique.

# %%
Theta = zeros(m,n);

for ii = 1:n
        ii
        ek = zeros(1,n);
        ek[ii] = 1;
        psi = idct(ek)';
        Theta[:,ii] = Phi*psi;
    end
#return Theta

# %% [markdown]
# ### II.1. Utilisation d'un algorithme de sous-gradient

# %% [markdown]
# ** Qestion 3 :** Soit $\lambda > 0$ (ici $\lambda=100$). Expliquer l'intérêt de
#  calculer $x_{sg}= \Psi z$ où $z$ résout $$\min_z \frac{1}{2} ||\Phi  \cdot \Psi  \cdot z -y||_2^2+ \lambda ||z||_1.$$
#
# ** Qestion 4 :** Justifier la convexité de la fonctionnelle et donner son sous-différentiel.
#
# ** Qestion 5 :** Compléter ci-dessous le code de sous-gradient projeté. Vous considèrerez les différents choix de pas $\alpha_i$ vus en cours, et trouverez des réglages permettant d'obtenir un bon rendu visuel. On pourra se rappeler du fait que la solution de norme minimale a une norme inférieure à dix.

# %%
z = zeros(k^2,1); i=0; lambda=1e-2;
choix_pas = 3; # 1 cas a, 2 cas b, 3 cas c
#pas3=1/g
#pas2=1/i-100

while i <= 1000
    ## A compléter   
    
    g = transpose(Theta)*(Theta*z-y);  
    i = i + 1;      
    
    for k = 1:(k^2)        
        if z[k]== 0 
            g[k] = g[k] + lambda;  
        else
           g[k] = g[k] + lambda*sign(z[k]);
        end            
    end   
    
    
    pas = (1)/(100*i);
   # pas = 1/(i*norm(g));
    z = z+pas*g;
    #y = Theta*z;
    ## fin à compléter

end


norm(Theta\y)
# Out:
# 8.759986405154299

# %% [markdown]
# **Question 5 :** Expliquer le code suivant et conclure sur l'utilisation du sous-gradient

# %%
function my_function(n,k,z)
    x2 = zeros(n,1);
    for ii = 1:n
        ii
        ek = zeros(1,n);
        ek[ii] = 1;
        psi = idct(ek)';
        x2 = x2+psi*z[ii];
    end
    x2 = reshape(x2,k,k);
    x2 = 1/(maximum(x2)-minimum(x2))*(x2-minimum(x2)*ones(k,k));
    return x2
end
#
x2 = my_function(n,k,z);
imhsv = colorview(Gray, float(x2));
tmp=@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.506753)  Gray{Float64}(0.49696)   …  Gray{Float64}(0.643561)
#  Gray{Float64}(0.223171)  Gray{Float64}(0.367601)     Gray{Float64}(0.17577)
#  Gray{Float64}(0.42956)   Gray{Float64}(0.387054)     Gray{Float64}(0.444694)
#  Gray{Float64}(0.608731)  Gray{Float64}(0.517205)     Gray{Float64}(0.560851)
#  Gray{Float64}(0.419729)  Gray{Float64}(0.353152)     Gray{Float64}(0.501621)
#  Gray{Float64}(0.653253)  Gray{Float64}(0.371425)  …  Gray{Float64}(0.727291)
#  Gray{Float64}(0.264892)  Gray{Float64}(0.377743)     Gray{Float64}(0.249542)
#  Gray{Float64}(0.342379)  Gray{Float64}(0.604039)     Gray{Float64}(0.46835)
#  Gray{Float64}(0.392416)  Gray{Float64}(0.585334)     Gray{Float64}(0.53765)
#  Gray{Float64}(0.386303)  Gray{Float64}(0.44417)      Gray{Float64}(0.332884)
#  Gray{Float64}(0.509105)  Gray{Float64}(0.390119)  …  Gray{Float64}(0.416601)
#  Gray{Float64}(0.392299)  Gray{Float64}(0.541697)     Gray{Float64}(0.326762)
#  Gray{Float64}(0.67943)   Gray{Float64}(0.474037)     Gray{Float64}(0.384849)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.367997)  Gray{Float64}(0.447397)     Gray{Float64}(0.400434)
#  Gray{Float64}(0.75683)   Gray{Float64}(0.823796)     Gray{Float64}(0.174255)
#  Gray{Float64}(0.401785)  Gray{Float64}(0.66919)   …  Gray{Float64}(0.564913)
#  Gray{Float64}(0.65456)   Gray{Float64}(0.70809)      Gray{Float64}(0.621666)
#  Gray{Float64}(0.525166)  Gray{Float64}(0.263313)     Gray{Float64}(0.466294)
#  Gray{Float64}(0.46089)   Gray{Float64}(0.703659)     Gray{Float64}(0.490094)
#  Gray{Float64}(0.654958)  Gray{Float64}(0.464522)     Gray{Float64}(0.612226)
#  Gray{Float64}(0.361626)  Gray{Float64}(0.312071)  …  Gray{Float64}(0.484893)
#  Gray{Float64}(0.318247)  Gray{Float64}(0.361418)     Gray{Float64}(0.369911)
#  Gray{Float64}(0.809082)  Gray{Float64}(0.298979)     Gray{Float64}(0.452642)
#  Gray{Float64}(0.387031)  Gray{Float64}(0.497023)     Gray{Float64}(0.449848)
#  Gray{Float64}(0.864956)  Gray{Float64}(0.547687)     Gray{Float64}(0.424575)

# %% [markdown]
# # II.2. Utilisation d'un algorithme de sous-gradient projeté

# %% [markdown]
# ** Question 6 :**  Expliquer l'intérêt de
#  calculer $x_{sgp}= \Psi z$ où $z$ résout $$\min_{\Phi  \cdot \Psi  \cdot z =y}  ||z||_1.$$

# %% [markdown]
# ** Question 7 :** Rappeler la formule de la projection sur le convexe $\{x, \Phi  \cdot \Psi  \cdot z =y \}$ vue en cours.

# %% [markdown]
# ** Question 8 :** Résoudre ce problème par l'algorithme de sous-gradient projeté et finaliser le calcul de la solution.

# %%
z = zeros(k^2,1); 
i=0;
choix_pas = 1; # 1 cas a, 2 cas b, 3 cas c

##Initialisation (possible)
## A compléter
A=Theta;
#Im = zeros(k^2,1);

#for i = 1:(k^2)
#    Im[i,1]=1;
#end

## Fin à compléter

while i <= 2000
    i = i + 1; 
    ## A compléter
    g = transpose(Theta)*(Theta*z-y);     
    for k = 1:(k^2)        
        if z[k]== 0 
            g[k] = g[k] + lambda;  
        else
            g[k] = g[k] + lambda*sign(z[k]);
        end            
    end 
    
   # if choix_pas == 1 
        pas = 1.7;  #pas 1
    #elseif choix_pas == 2
     #   pas = (1)/i; #pas 2 
    #else
     #   pas = 1/(i*norm(g)); #pas 3
    #end
    zi=z-pas*g;
    z = zi -transpose(A)*inv(A*transpose(A))*(A*zi-y);
    #z = z -pas*(Im -transpose(A)*inv(A*transpose(A))*A)*g;
    #y = Theta*z;
    
    
    ## Fin à compléter
end

# %%
x3 = my_function(n,k,z);
imhsv = colorview(Gray,float(x3));
tmp =@view imhsv[:,:]
# Out:
# 30×30 view(reinterpret(Gray{Float64}, ::Array{Float64,2}), :, :) with eltype Gray{Float64}:
#  Gray{Float64}(0.795742)   …  Gray{Float64}(0.778201)
#  Gray{Float64}(0.770023)      Gray{Float64}(0.823395)
#  Gray{Float64}(0.729472)      Gray{Float64}(0.754949)
#  Gray{Float64}(0.754308)      Gray{Float64}(0.836442)
#  Gray{Float64}(0.754741)      Gray{Float64}(0.734001)
#  Gray{Float64}(0.818541)   …  Gray{Float64}(0.77791)
#  Gray{Float64}(0.66766)       Gray{Float64}(0.674368)
#  Gray{Float64}(0.729938)      Gray{Float64}(0.331525)
#  Gray{Float64}(0.668599)      Gray{Float64}(0.218237)
#  Gray{Float64}(0.691922)      Gray{Float64}(0.265543)
#  Gray{Float64}(0.822711)   …  Gray{Float64}(0.263902)
#  Gray{Float64}(0.775422)      Gray{Float64}(0.185197)
#  Gray{Float64}(0.817313)      Gray{Float64}(0.162684)
#  ⋮                         ⋱
#  Gray{Float64}(0.528367)      Gray{Float64}(0.0932321)
#  Gray{Float64}(0.297921)      Gray{Float64}(0.0905723)
#  Gray{Float64}(0.268347)   …  Gray{Float64}(0.191876)
#  Gray{Float64}(0.195176)      Gray{Float64}(0.12076)
#  Gray{Float64}(0.275397)      Gray{Float64}(0.0771438)
#  Gray{Float64}(0.21923)       Gray{Float64}(0.231098)
#  Gray{Float64}(0.209943)      Gray{Float64}(0.178538)
#  Gray{Float64}(0.247547)   …  Gray{Float64}(0.247993)
#  Gray{Float64}(0.237757)      Gray{Float64}(0.265933)
#  Gray{Float64}(0.0278804)     Gray{Float64}(0.184477)
#  Gray{Float64}(0.198717)      Gray{Float64}(0.241679)
#  Gray{Float64}(0.35266)       Gray{Float64}(0.275079)
